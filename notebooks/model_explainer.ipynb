# %% [markdown]
# # Model Explainability

# %%
import sys
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
sys.path.append('../scripts/model_explainers')
from model_explainer import *
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)

# %% [markdown]
# ### Load trained model , test and train files

# %%
import joblib
model_path = '../models/fraudIP_xgb_model.pkl'

# Load the model
model = joblib.load(model_path)
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
X_train = pd.read_csv(os.path.join('../data/model_inputs', 'X_train.csv'))
X_test = pd.read_csv(os.path.join('../data/model_inputs', 'X_test.csv'))

# %% [markdown]
# ### Model Explainability Using SHAP

# %%
feature_name = 'device_reuse_encoded'
explain_with_shap(model, X_test, feature_name)

# %% [markdown]
# ### Model Explainability Using LIME

# %%
explain_with_lime(model, X_test)
