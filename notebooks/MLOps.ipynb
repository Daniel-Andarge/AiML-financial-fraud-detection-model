# %%
import sys
import os
import random
import calendar
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm, skew, ttest_ind
import warnings
warnings.filterwarnings('ignore')
sys.path.append('../scripts')
from data_loader import *
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)

# %%
from mlops_pipeline import ModelTrainingPipeline

# %%
pipeline = ModelTrainingPipeline()
pipeline.run_pipeline()
# Out:
# Experiment logged for model 1 with run ID: 06697df332774a7d810d352e15c16ee4
# Experiment logged for model 2 with run ID: 06697df332774a7d810d352e15c16ee4
# Experiment logged for model 3 with run ID: 06697df332774a7d810d352e15c16ee4
# Metrics for XGBoost:
#                     Metric        Value
# 0      Not Fraud_precision     0.765032
# 1         Not Fraud_recall     0.922710
# 2       Not Fraud_f1-score     0.836505
# 3        Not Fraud_support  2096.000000
# 4          Fraud_precision     0.902644
# 5             Fraud_recall     0.716603
# 6           Fraud_f1-score     0.798936
# 7            Fraud_support  2096.000000
# 8                 accuracy     0.819656
# 9      macro avg_precision     0.833838
# 10        macro avg_recall     0.819656
# 11      macro avg_f1-score     0.817721
# 12       macro avg_support  4192.000000
# 13  weighted avg_precision     0.833838
# 14     weighted avg_recall     0.819656
# 15   weighted avg_f1-score     0.817721
# 16    weighted avg_support  4192.000000
#
# Metrics for MLP:
#                     Metric        Value
# 0              0_precision     0.738760
# 1                 0_recall     0.744752
# 2               0_f1-score     0.741744
# 3                0_support  2096.000000
# 4              1_precision     0.742665
# 5                 1_recall     0.736641
# 6               1_f1-score     0.739641
# 7                1_support  2096.000000
# 8                 accuracy     0.740697
# 9      macro avg_precision     0.740712
# 10        macro avg_recall     0.740697
# 11      macro avg_f1-score     0.740692
# 12       macro avg_support  4192.000000
# 13  weighted avg_precision     0.740712
# 14     weighted avg_recall     0.740697
# 15   weighted avg_f1-score     0.740692
# 16    weighted avg_support  4192.000000
#
# Metrics for RandomForest:
#                     Metric        Value
# 0      Not Fraud_precision     0.762928
# 1         Not Fraud_recall     0.915076
# 2       Not Fraud_f1-score     0.832104
# 3        Not Fraud_support  2096.000000
# 4          Fraud_precision     0.893921
# 5             Fraud_recall     0.715649
# 6           Fraud_f1-score     0.794913
# 7            Fraud_support  2096.000000
# 8                 accuracy     0.815363
# 9      macro avg_precision     0.828424
# 10        macro avg_recall     0.815363
# 11      macro avg_f1-score     0.813508
# 12       macro avg_support  4192.000000
# 13  weighted avg_precision     0.828424
# 14     weighted avg_recall     0.815363
# 15   weighted avg_f1-score     0.813508
# 16    weighted avg_support  4192.000000
# Best model saved with F1-score for 'Fraud' class: 0.7396407185628743
